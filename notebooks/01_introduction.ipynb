# %% [markdown]
# # LLMs and Chat Models

# %%
from langchain_openai import OpenAI
from langchain.chat_models import ChatOpanAI
from langchain.chat_models import ChatAnthropic

llm = OpenAI()
chat = ChatOpenAI()

a = llm.predict()
b = chat.predict()
